# %%
from sklearn import datasets
from sklearn.utils.validation import check_random_state
from sklearn.model_selection import StratifiedKFold, cross_val_score
from rgf.sklearn import RGFClassifier

iris = datasets.load_iris()
rng = check_random_state(0)
perm = rng.permutation(iris.target.size)
iris.data = iris.data[perm]
iris.target = iris.target[perm]

rgf = RGFClassifier(max_leaf=400,
                    algorithm="RGF_Sib",
                    test_interval=100,
                    verbose=True)

n_folds = 3

rgf_scores = cross_val_score(rgf,
                             iris.data,
                             iris.target,
                             cv=StratifiedKFold(n_folds))

rgf_score = sum(rgf_scores)/n_folds
print('RGF Classfier score: {0:.5f}'.format(rgf_score))
# Out:
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.train.data.x
#    train_y_fn=/tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.model
# --------------------
# Sat Apr 14 05:55:33 2018: Reading training data ...
# Sat Apr 14 05:55:33 2018: Start ... #train=99
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x99, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:33 2018: Calling optimizer with 29 trees and 101 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=1
# Sat Apr 14 05:55:33 2018: Calling optimizer with 57 trees and 200 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=2
# Sat Apr 14 05:55:33 2018: Calling optimizer with 85 trees and 300 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=3
# Sat Apr 14 05:55:33 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:33 2018: Calling optimizer with 115 trees and 401 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.model-01
# /tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.model-02
# /tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.model-03
# /tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.model-04
#
# Sat Apr 14 05:55:33 2018: Done ...
# elapsed: 0.011525
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.train.data.x
#    train_y_fn=/tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.model
# --------------------
# Sat Apr 14 05:55:33 2018: Reading training data ...
# Sat Apr 14 05:55:33 2018: Start ... #train=99
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x99, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:33 2018: Calling optimizer with 50 trees and 100 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=1
# Sat Apr 14 05:55:33 2018: Calling optimizer with 100 trees and 200 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=2
# Sat Apr 14 05:55:33 2018: Calling optimizer with 150 trees and 300 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=3
# Sat Apr 14 05:55:33 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:33 2018: Calling optimizer with 200 trees and 400 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.model-01
# /tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.model-02
# /tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.model-03
# /tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.model-04
#
# Sat Apr 14 05:55:33 2018: Done ...
# elapsed: 0.014402
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.train.data.x
#    train_y_fn=/tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.model
# --------------------
# Sat Apr 14 05:55:33 2018: Reading training data ...
# Sat Apr 14 05:55:33 2018: Start ... #train=99
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x99, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:33 2018: Calling optimizer with 34 trees and 100 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=1
# Sat Apr 14 05:55:33 2018: Calling optimizer with 71 trees and 200 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=2
# Sat Apr 14 05:55:33 2018: Calling optimizer with 112 trees and 300 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=3
# Sat Apr 14 05:55:33 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:33 2018: Calling optimizer with 152 trees and 400 leaves
# Sat Apr 14 05:55:33 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.model-01
# /tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.model-02
# /tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.model-03
# /tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.model-04
#
# Sat Apr 14 05:55:33 2018: Done ...
# elapsed: 0.013294
#
#
#
# None
# None
# None
# "predict":
#    model_fn=/tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.model-04
#    test_x_fn=/tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.test.data.x
#    prediction_fn=/tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.00018
# /tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.predictions.txt: /tmp/rgf/7f085da4-87d7-4962-8f00-907e58c3852a19.model-04,#leaf=400,#tree=200
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "predict":
#    model_fn=/tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.model-04
#    test_x_fn=/tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.test.data.x
#    prediction_fn=/tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000185
# /tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.predictions.txt: /tmp/rgf/7c48d454-3556-4e6d-9947-e7d247abe38920.model-04,#leaf=401,#tree=115
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "predict":
#    model_fn=/tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.model-04
#    test_x_fn=/tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.test.data.x
#    prediction_fn=/tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000231
# /tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.predictions.txt: /tmp/rgf/e26975ca-0dcd-48f6-af98-dd5ee8ea68fc21.model-04,#leaf=400,#tree=152
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.train.data.x
#    train_y_fn=/tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.model
# --------------------
# Sat Apr 14 05:55:34 2018: Reading training data ...
# Sat Apr 14 05:55:34 2018: Start ... #train=99
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x99, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:34 2018: Calling optimizer with 28 trees and 100 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=1
# Sat Apr 14 05:55:34 2018: Calling optimizer with 57 trees and 200 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=2
# Sat Apr 14 05:55:34 2018: Calling optimizer with 86 trees and 300 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=3
# Sat Apr 14 05:55:34 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:34 2018: Calling optimizer with 115 trees and 400 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.model-01
# /tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.model-02
# /tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.model-03
# /tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.model-04
#
# Sat Apr 14 05:55:34 2018: Done ...
# elapsed: 0.011113
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.train.data.x
#    train_y_fn=/tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.model
# --------------------
# Sat Apr 14 05:55:34 2018: Reading training data ...
# Sat Apr 14 05:55:34 2018: Start ... #train=99
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x99, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:34 2018: Calling optimizer with 41 trees and 101 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=1
# Sat Apr 14 05:55:34 2018: Calling optimizer with 83 trees and 200 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=2
# Sat Apr 14 05:55:34 2018: Calling optimizer with 124 trees and 300 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=3
# Sat Apr 14 05:55:34 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:34 2018: Calling optimizer with 165 trees and 400 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.model-01
# /tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.model-02
# /tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.model-03
# /tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.model-04
#
# Sat Apr 14 05:55:34 2018: Done ...
# elapsed: 0.012764
# None
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.train.data.x
#    train_y_fn=/tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.model
# --------------------
# Sat Apr 14 05:55:34 2018: Reading training data ...
# Sat Apr 14 05:55:34 2018: Start ... #train=99
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x99, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:34 2018: Calling optimizer with 50 trees and 100 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=1
# Sat Apr 14 05:55:34 2018: Calling optimizer with 100 trees and 200 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=2
# Sat Apr 14 05:55:34 2018: Calling optimizer with 150 trees and 300 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=3
# Sat Apr 14 05:55:34 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:34 2018: Calling optimizer with 200 trees and 400 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.model-01
# /tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.model-02
# /tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.model-03
# /tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.model-04
#
# Sat Apr 14 05:55:34 2018: Done ...
# elapsed: 0.013726
#
#
# None
# None
# "predict":
#    model_fn=/tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.model-04
#    test_x_fn=/tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.test.data.x
#    prediction_fn=/tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000194
# /tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.predictions.txt: /tmp/rgf/1e620232-f418-4897-b5d5-a10200559b5822.model-04,#leaf=400,#tree=200
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "predict":
#    model_fn=/tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.model-04
#    test_x_fn=/tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.test.data.x
#    prediction_fn=/tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000189
# /tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.predictions.txt: /tmp/rgf/b4f8f76d-55f1-45d8-a32e-6e7e2364f21c23.model-04,#leaf=400,#tree=115
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "predict":
#    model_fn=/tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.model-04
#    test_x_fn=/tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.test.data.x
#    prediction_fn=/tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000211
# /tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.predictions.txt: /tmp/rgf/e5f6a8ea-0dca-4b0d-9acb-9012552b377024.model-04,#leaf=400,#tree=165
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.train.data.x
#    train_y_fn=/tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.model
# --------------------
# Sat Apr 14 05:55:34 2018: Reading training data ...
# Sat Apr 14 05:55:34 2018: Start ... #train=102
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x102, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:34 2018: Calling optimizer with 33 trees and 100 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=1
# Sat Apr 14 05:55:34 2018: Calling optimizer with 63 trees and 200 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=2
# Sat Apr 14 05:55:34 2018: Calling optimizer with 94 trees and 301 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=3
# Sat Apr 14 05:55:34 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:34 2018: Calling optimizer with 125 trees and 400 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.model-01
# /tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.model-02
# /tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.model-03
# /tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.model-04
#
# Sat Apr 14 05:55:34 2018: Done ...
# elapsed: 0.012559
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.train.data.x
#    train_y_fn=/tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.model
# --------------------
# Sat Apr 14 05:55:34 2018: Reading training data ...
# Sat Apr 14 05:55:34 2018: Start ... #train=102
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x102, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:34 2018: Calling optimizer with 45 trees and 101 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=1
# Sat Apr 14 05:55:34 2018: Calling optimizer with 86 trees and 200 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=2
# Sat Apr 14 05:55:34 2018: Calling optimizer with 127 trees and 301 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=3
# Sat Apr 14 05:55:34 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:34 2018: Calling optimizer with 169 trees and 401 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.model-01
# /tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.model-02
# /tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.model-03
# /tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.model-04
#
# Sat Apr 14 05:55:34 2018: Done ...
# elapsed: 0.0137
# "train":
#    algorithm=RGF_Sib
#    train_x_fn=/tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.train.data.x
#    train_y_fn=/tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.train.data.y
#    Log:ON
#    model_fn_prefix=/tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.model
# --------------------
# Sat Apr 14 05:55:34 2018: Reading training data ...
# Sat Apr 14 05:55:34 2018: Start ... #train=102
# --------------------
# Forest-level:
#    loss=Log
#    max_leaf_forest=400
#    max_tree=200
#    opt_interval=100
#    test_interval=100
#    num_tree_search=1
#    Verbose:ON
#    memory_policy=Generous
# Turning on Force_to_refresh_all
# -------------
# Training data: 4x102, nonzero_ratio=1; managed as dense data.
# -------------
# Optimization:
#    loss=Log
#    num_iteration_opt=5
#    reg_L2=0.1
#    opt_stepsize=0.5
#    max_delta=1
# Tree-level: min_pop=10
# Node split: reg_L2=0.1
# --------------------
# Sat Apr 14 05:55:34 2018: Calling optimizer with 50 trees and 100 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=1
# Sat Apr 14 05:55:34 2018: Calling optimizer with 100 trees and 200 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=2
# Sat Apr 14 05:55:34 2018: Calling optimizer with 150 trees and 300 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=3
# Sat Apr 14 05:55:34 2018: AzRgforest: #leaf reached max
# Sat Apr 14 05:55:34 2018: Calling optimizer with 200 trees and 400 leaves
# Sat Apr 14 05:55:34 2018: Writing model: seq#=4
#
# Generated 4 model file(s):
# /tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.model-01
# /tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.model-02
# /tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.model-03
# /tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.model-04
#
# Sat Apr 14 05:55:34 2018: Done ...
# elapsed: 0.01424
# None
#
#
# None
# None
# "predict":
#    model_fn=/tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.model-04
#    test_x_fn=/tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.test.data.x
#    prediction_fn=/tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000196
# /tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.predictions.txt: /tmp/rgf/fdb0d34e-06df-4141-b25f-106d348e5ee125.model-04,#leaf=400,#tree=200
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "predict":
#    model_fn=/tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.model-04
#    test_x_fn=/tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.test.data.x
#    prediction_fn=/tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000185
# /tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.predictions.txt: /tmp/rgf/b572ca4d-5349-41af-b5f5-66e4d3701a7c26.model-04,#leaf=400,#tree=125
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# "predict":
#    model_fn=/tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.model-04
#    test_x_fn=/tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.test.data.x
#    prediction_fn=/tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.predictions.txt
#    Log:ON
# --------------------
# Sat Apr 14 05:55:34 2018: Reading test data ...
# Sat Apr 14 05:55:34 2018: Predicting ...
# elapsed: 0.000209
# /tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.predictions.txt: /tmp/rgf/04bb25db-8f38-43d2-9834-d9843964ce8d27.model-04,#leaf=401,#tree=169
# Sat Apr 14 05:55:34 2018: Done ...
#
# None
# RGF Classfier score: 0.95997

# %%
RGFClassifier
# Out:
# rgf.rgf_model.RGFClassifier
