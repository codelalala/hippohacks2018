# %%
import numpy as np
import pandas as pd

# %%
ls data/
# Out:
# data_cleaned_1st(2).xlsx                          spray.csv
# mapdata_copyright_openstreetmap_contributors.rds  test.csv
# mapdata_copyright_openstreetmap_contributors.txt  train.csv
# noaa_weather_qclcd_documentation.pdf              weather.csv
# sampleSubmission.csv                              west_nile/

# %% [markdown]
# Id: the id of the record
# Date: date that the WNV test is performed
# Address: approximate address of the location of trap. This is used to send to the GeoCoder.
# Species: the species of mosquitos
# Block: block number of address
# Street: street name
# Trap: Id of the trap
# AddressNumberAndStreet: approximate address returned from GeoCoder
# Latitude, Longitude: Latitude and Longitude returned from GeoCoder
# AddressAccuracy: accuracy returned from GeoCoder
# NumMosquitos: number of mosquitoes caught in this trap
# WnvPresent: whether West Nile Virus was present in these mosquitos. 1 means WNV is present, and 0 means not present.

# %%
name=['Date','Address','Species','Block','Street','Trap','AddressNumberAndStreet','Latitue','AddressAccuracy','NumMosquitos','WnvPresent']

# %%
train_set=pd.read_csv('data/train.csv',header=0)
validation_set=pd.read_csv('data/validation.csv',header=0)
weather=pd.read_csv('data/weather.csv',header=0)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 12 columns):
# Date                      10506 non-null object
# Address                   10506 non-null object
# Species                   10506 non-null object
# Block                     10506 non-null int64
# Street                    10506 non-null object
# Trap                      10506 non-null object
# AddressNumberAndStreet    10506 non-null object
# Latitude                  10506 non-null float64
# Longitude                 10506 non-null float64
# AddressAccuracy           10506 non-null int64
# NumMosquitos              10506 non-null int64
# WnvPresent                10506 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 985.0+ KB

# %%
validation_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55883 entries, 0 to 55882
# Data columns (total 11 columns):
# Id                        55883 non-null int64
# Date                      55883 non-null object
# Address                   55883 non-null object
# Species                   55883 non-null object
# Block                     55883 non-null int64
# Street                    55883 non-null object
# Trap                      55883 non-null object
# AddressNumberAndStreet    55883 non-null object
# Latitude                  55883 non-null float64
# Longitude                 55883 non-null float64
# AddressAccuracy           55883 non-null int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 4.7+ MB

# %%
combined_set = pd.concat([train_set, validation_set], axis = 0)
combined_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66389 entries, 0 to 55882
# Data columns (total 13 columns):
# Address                   66389 non-null object
# AddressAccuracy           66389 non-null int64
# AddressNumberAndStreet    66389 non-null object
# Block                     66389 non-null int64
# Date                      66389 non-null object
# Id                        55883 non-null float64
# Latitude                  66389 non-null float64
# Longitude                 66389 non-null float64
# NumMosquitos              10506 non-null float64
# Species                   66389 non-null object
# Street                    66389 non-null object
# Trap                      66389 non-null object
# WnvPresent                10506 non-null float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 7.1+ MB

# %%
combined_set=combined_set['Species']

# %%
combined_set
# Out:
# 0        CULEX PIPIENS/RESTUANS
# 1                CULEX RESTUANS
# 2                CULEX RESTUANS
# 3        CULEX PIPIENS/RESTUANS
# 4                CULEX RESTUANS
# 5                CULEX RESTUANS
# 6                CULEX RESTUANS
# 7        CULEX PIPIENS/RESTUANS
# 8                CULEX RESTUANS
# 9                CULEX RESTUANS
# 10       CULEX PIPIENS/RESTUANS
# 11       CULEX PIPIENS/RESTUANS
# 12               CULEX RESTUANS
# 13       CULEX PIPIENS/RESTUANS
# 14               CULEX RESTUANS
# 15               CULEX RESTUANS
# 16               CULEX RESTUANS
# 17               CULEX RESTUANS
# 18                CULEX PIPIENS
# 19       CULEX PIPIENS/RESTUANS
# 20               CULEX RESTUANS
# 21       CULEX PIPIENS/RESTUANS
# 22       CULEX PIPIENS/RESTUANS
# 23               CULEX RESTUANS
# 24               CULEX RESTUANS
# 25       CULEX PIPIENS/RESTUANS
# 26               CULEX RESTUANS
# 27                CULEX PIPIENS
# 28       CULEX PIPIENS/RESTUANS
# ...

# %%
combined_set['Species']=pd.Categorical(combined_set['Species']).codes

# %%
test=pd.get_dummies(combined_set,prefix=['Species'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-eb0af7a26579> in <module>()
# ----> 1 test=pd.get_dummies(combined_set,prefix=['Species'])
#
# /opt/anaconda/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1183                     raise ValueError(len_msg)
#    1184
# -> 1185         check_len(prefix, 'prefix')
#    1186         check_len(prefix_sep, 'prefix_sep')
#    1187         if isinstance(prefix, compat.string_types):
#
# /opt/anaconda/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in check_len(item, name)
#    1181                     len_msg = len_msg.format(name=name, len_item=len(item),
#    1182                                              len_enc=len(columns_to_encode))
# -> 1183                     raise ValueError(len_msg)
#    1184
# ...

# %%
combined_set
# Out:
#                                                  Address  AddressAccuracy  \
# 0      4100 North Oak Park Avenue, Chicago, IL 60634,...                9
# 1      4100 North Oak Park Avenue, Chicago, IL 60634,...                9
# 2      6200 North Mandell Avenue, Chicago, IL 60646, USA                9
# 3        7900 West Foster Avenue, Chicago, IL 60656, USA                8
# 4        7900 West Foster Avenue, Chicago, IL 60656, USA                8
# 5       1500 West Webster Avenue, Chicago, IL 60614, USA                8
# 6         2500 West Grand Avenue, Chicago, IL 60654, USA                8
# 7            1100 Roosevelt Road, Chicago, IL 60608, USA                8
# 8            1100 Roosevelt Road, Chicago, IL 60608, USA                8
# 9       1100 West Chicago Avenue, Chicago, IL 60642, USA                8
# 10       2100 North Stave Street, Chicago, IL 60647, USA                8
# 11       2200 North Cannon Drive, Chicago, IL 60614, USA                8
# ...

# %%
train_set_part=train_set[['Species']]
train_set_part['Species']=pd.Categorical(train_set_part['Species']).codes
train_set_part
# Out:
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Species
# 0            2
# 1            3
# 2            3
# 3            2
# 4            3
# 5            3
# 6            3
# 7            2
# 8            3
# 9            3
# 10           2
# 11           2
# 12           3
# 13           2
# 14           3
# 15           3
# 16           3
# 17           3
# 18           1
# 19           2
# 20           3
# 21           2
# 22           2
# 23           3
# 24           3
# 25           2
# 26           3
# 27           1
# 28           2
# 29           3
# ...        ...
# 10476        2
# 10477        3
# 10478        1
# 10479        1
# 10480        2
# 10481        3
# ...
